# %% [markdown]
# # **Helmet Detection**

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="45uabMzSMtq66rt1Awdg")
project = rf.workspace("nckh-2023").project("helmet-detection-project")
version = project.version(19)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # **Train Model**

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s.pt")

# Train the model
train_results = model.train(
    data="/content/Helmet-Detection-Project-19/data.yaml",  # path to dataset YAML
    epochs=10,  # number of training epochs
    imgsz=640,  # training image size
)
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # **Evaluasi**

# %%
# Evaluate model performance on the validation set
metrics = model.val()

# %% [markdown]
# # **Test**

# %%
# Perform object detection on an image
results = model("/content/Helmet-Detection-Project-19/test/images/IMG_5070_MOV-117_jpg.rf.b368669c53758bf18c54ada1f83f5882.jpg")
results[0].show()
# Out:
# image 1/1 /content/Helmet-Detection-Project-19/test/images/IMG_5070_MOV-117_jpg.rf.b368669c53758bf18c54ada1f83f5882.jpg: 384x640 1 helmet, 1 motorcyclist, 13.0ms
# Speed: 2.2ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
from ultralytics import YOLO

# Load model YOLO
model = YOLO("best.pt")

# Convert ke ONNX
model.export(format="onnx")  # Ini akan menghasilkan file "best.onnx"
